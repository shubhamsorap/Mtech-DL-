# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
#2
df2 = pd.read_csv('automobileEDA.csv')

# %%
#3
df2.shape , 
df2.dtypes
# Out:
# symboling              int64
# normalized-losses      int64
# make                  object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# city-L/100km         float64
# horsepower-binned     object
# diesel                 int64
# gas                    int64
# dtype: object

# %%
#4. cal corr
df2['engine-size'].corr(df2['price'])
# Out:
# 0.8723351674455189

# %%
#4
df2[['engine-size', 'price']].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %%
#5
df2.corr()['price']
# Out:
# symboling           -0.082391
# normalized-losses    0.133999
# wheel-base           0.584642
# length               0.690628
# width                0.751265
# height               0.135486
# curb-weight          0.834415
# engine-size          0.872335
# bore                 0.543155
# stroke               0.082310
# compression-ratio    0.071107
# horsepower           0.809575
# peak-rpm            -0.101616
# city-mpg            -0.686571
# highway-mpg         -0.704692
# price                1.000000
# city-L/100km         0.789898
# diesel               0.110326
# gas                 -0.110326
# Name: price, dtype: float64

# %%
#6
df2['peak-rpm'].dtype
# Out:
# dtype('float64')

# %%
#7
sns.regplot(df2['engine-size'], df2['price'])

# %%
#8
sns.pairplot(df2, y_vars=['price'], x_vars=df2.select_dtypes('float64').columns, kind='reg')

# %%
#10
plt.figure(figsize=(15,11))
ax = sns.heatmap(df2.corr(), annot=True, cmap="coolwarm")
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
#11
sns.catplot(x='body-style', y='price', data=df2, kind='box', height=4, aspect=2)

# %%
#11 
sns.boxplot(x=df2["price"],y=df2["body-style"])

# %%
#12
sns.boxplot(x=df2["price"],y=df2["engine-type"])

# %%
sns.boxplot(x=df2["price"],y=df2["num-of-doors"])

# %%
sns.boxplot(x=df2["price"],y=df2["drive-wheels"])

# %%
sns.boxplot(x=df2["price"],y=df2["num-of-cylinders"])

# %%
sns.boxplot(x=df2["price"],y=df2["fuel-system"])

# %% [markdown]
# #13
# Boxplot tells us about the outliers and what their values are, it can also tell us if our data is symmetrical and
# how tightly our data is grouped.
# from the above boxplots, we can observe the outliers in the different variables, maximum and minimum values of each
# unique categorical values in each column and how much they vary from each other w.r.t price.

# %%
#14
df2.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %%
#15
df2.describe(include='object')
# Out:
#           make aspiration num-of-doors body-style drive-wheels  \
# count      201        201          201        201          201
# unique      22          2            2          5            3
# top     toyota        std         four      sedan          fwd
# freq        32        165          115         94          118
#
#        engine-location engine-type num-of-cylinders fuel-system  \
# count              201         201              201         201
# unique               2           6                7           8
# top              front         ohc             four        mpfi
# freq               198         145              157          92
#
#        horsepower-binned
# count                200
# unique                 3
# top                  Low
# freq                 115

# %%
#16
categorical_columns=df2.columns[df2.dtypes=='object']
for i in categorical_columns:
    print(str(i)+'->column unique values are :\n'+str(df2[i].value_counts()))
# Out:
# make->column unique values are :
# toyota           32
# nissan           18
# mazda            17
# honda            13
# mitsubishi       13
# volkswagen       12
# subaru           12
# peugot           11
# volvo            11
# dodge             9
# bmw               8
# mercedes-benz     8
# plymouth          7
# audi              6
# saab              6
# porsche           4
# alfa-romero       3
# jaguar            3
# chevrolet         3
# isuzu             2
# renault           2
# mercury           1
# Name: make, dtype: int64
# aspiration->column unique values are :
# std      165
# turbo     36
# Name: aspiration, dtype: int64
# num-of-doors->column unique values are :
# four    115
# two      86
# Name: num-of-doors, dtype: int64
# body-style->column unique values are :
# sedan          94
# hatchback      68
# wagon          25
# hardtop         8
# convertible     6
# Name: body-style, dtype: int64
# drive-wheels->column unique values are :
# fwd    118
# rwd     75
# ...

# %%
#17
df2.groupby('drive-wheels').mean()['price']
# Out:
# drive-wheels
# 4wd    10241.000000
# fwd     9244.779661
# rwd    19757.613333
# Name: price, dtype: float64

# %%
#18
categorical_columns=df2.columns[df2.dtypes=='object']
for i in categorical_columns:
    print(df2.groupby(i).mean()['price'])
    print('---------------------------------')
# Out:
# make
# alfa-romero      15498.333333
# audi             17859.166667
# bmw              26118.750000
# chevrolet         6007.000000
# dodge             7875.444444
# honda             8184.692308
# isuzu             8916.500000
# jaguar           34600.000000
# mazda            10652.882353
# mercedes-benz    33647.000000
# mercury          16503.000000
# mitsubishi        9239.769231
# nissan           10415.666667
# peugot           15489.090909
# plymouth          7963.428571
# porsche          31400.500000
# renault           9595.000000
# saab             15223.333333
# subaru            8541.250000
# toyota            9885.812500
# volkswagen       10077.500000
# volvo            18063.181818
# Name: price, dtype: float64
# ---------------------------------
# aspiration
# std      12542.181818
# turbo    16254.805556
# Name: price, dtype: float64
# ---------------------------------
# num-of-doors
# four    13498.034783
# two     12818.127907
# Name: price, dtype: float64
# ...

# %%
#19
df2=df2.groupby(['drive-wheels','body-style']).mean()['price']
print(df2)
# Out:
# drive-wheels  body-style
# 4wd           hatchback       7603.000000
#               sedan          12647.333333
#               wagon           9095.750000
# fwd           convertible    11595.000000
#               hardtop         8249.000000
#               hatchback       8396.387755
#               sedan           9811.800000
#               wagon           9997.333333
# rwd           convertible    23949.600000
#               hardtop        24202.714286
#               hatchback      14337.777778
#               sedan          21711.833333
#               wagon          16994.222222
# Name: price, dtype: float64

# %%
#20
df2.reset_index().pivot_table(index='drive-wheels',columns='body-style')
# Out:
#                    price                                            \
# body-style   convertible       hardtop     hatchback         sedan
# drive-wheels
# 4wd                  NaN           NaN   7603.000000  12647.333333
# fwd              11595.0   8249.000000   8396.387755   9811.800000
# rwd              23949.6  24202.714286  14337.777778  21711.833333
#
#
# body-style           wagon
# drive-wheels
# 4wd            9095.750000
# fwd            9997.333333
# rwd           16994.222222

# %%
#21
gb1=df2.groupby(['engine-location','engine-type']).mean()['price']
gb1.reset_index().pivot_table(index='engine-location',columns='engine-type')
# Out:
#                         price                                        \
# engine-type              dohc             l           ohc      ohcf
# engine-location
# front            18116.416667  14627.583333  11567.358621   8541.25
# rear                      NaN           NaN           NaN  34528.00
#
#
# engine-type              ohcv    rotor
# engine-location
# front            25098.384615  13020.0
# rear                      NaN      NaN

# %%
gb2=df2.groupby(['fuel-system','horsepower-binned']).mean()['price']
gb2.reset_index().pivot_table(index='fuel-system',columns='horsepower-binned')
# Out:
#                           price
# horsepower-binned          High           Low        Medium
# fuel-system
# 1bbl                        NaN   7555.545455           NaN
# 2bbl                        NaN   7433.203125           NaN
# 4bbl                        NaN  12145.000000           NaN
# idi                         NaN  12047.800000  27209.200000
# mfi                         NaN           NaN  12964.000000
# mpfi               25899.130435  11871.904762  15716.659574
# spdi                        NaN           NaN  10990.444444
# spfi                        NaN  11048.000000           NaN

# %%
#22
sns.heatmap(df2.reset_index().pivot_table(index='drive-wheels',columns='body-style'))

# %%
#23
from scipy.stats import pearsonr
corr, _ = pearsonr(df2['wheel-base'],df2['price'])
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.585

# %%
#24
from scipy.stats import f_oneway
f_oneway(df2['price'][df2['drive-wheels'] == '4wd'],
               df2['price'][df2['drive-wheels'] == 'fwd'],
               df2['price'][df2['drive-wheels'] == 'rwd'])
# Out:
# F_onewayResult(statistic=67.95406500780399, pvalue=3.3945443577151245e-23)

# %% [markdown]
# #
# F-statistic=67.95 suggests the between-groups variance is 67x the within-group variance
# p-value is <0.05, so we reject null hypothesis i.e, both are correlated and the result is significant .
